# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 779

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | mogadishu
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | jaunjelgava
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 1 | vila velha
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | little baguio
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | miandoab
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | varna
# Processing Record 22 of Set 1 | smithers
# Processing Record 23 of Set 1 | jalu
# Processing Record 24 of Set 1 | teahupoo
# Processing Record 25 of Set 1 | luena
# Processing Record 26 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | parrita
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | pangnirtung
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | los llanos de aridane
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | paamiut
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | sabang
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | gladstone
# Processing Record 5 of Set 2 | mormugao
# Processing Record 6 of Set 2 | sakakah
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | manicore
# Processing Record 9 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 2 | canyon
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | umea
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | mantua
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | dwarka
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | shahpur
# Processing Record 19 of Set 2 | cherepanovo
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | peniche
# Processing Record 24 of Set 2 | darlowo
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | antofagasta
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 34 of Set 2 | huarmey
# Processing Record 35 of Set 2 | puri
# Processing Record 36 of Set 2 | laguna
# Processing Record 37 of Set 2 | tabas
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | macusani
# Processing Record 41 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | galesong
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | pochutla
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | brae
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | keti bandar
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | yumen
# Processing Record 4 of Set 3 | vao
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | yaan
# Processing Record 7 of Set 3 | ulety
# Processing Record 8 of Set 3 | usinsk
# Processing Record 9 of Set 3 | baykit
# Processing Record 10 of Set 3 | deputatskiy
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | rizhao
# Processing Record 14 of Set 3 | fort nelson
# Processing Record 15 of Set 3 | mezen
# Processing Record 16 of Set 3 | maniitsoq
# Processing Record 17 of Set 3 | valdez
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | lima
# Processing Record 20 of Set 3 | meteti
# Processing Record 21 of Set 3 | bafoulabe
# Processing Record 22 of Set 3 | zenzeli
# Processing Record 23 of Set 3 | hay river
# Processing Record 24 of Set 3 | jasper
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | tigil
# Processing Record 27 of Set 3 | llanes
# Processing Record 28 of Set 3 | puerto del rosario
# Processing Record 29 of Set 3 | ulladulla
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | guerrero negro
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | flinders
# Processing Record 34 of Set 3 | sungaipenuh
# Processing Record 35 of Set 3 | jiazi
# Processing Record 36 of Set 3 | kyshtovka
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | sinnamary
# Processing Record 41 of Set 3 | chaman
# Processing Record 42 of Set 3 | the valley
# Processing Record 43 of Set 3 | suntar
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | salinopolis
# Processing Record 46 of Set 3 | arlit
# Processing Record 47 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 3 | galle
# Processing Record 49 of Set 3 | dodge city
# Processing Record 50 of Set 3 | rolla
# Processing Record 1 of Set 4 | mahanoro
# Processing Record 2 of Set 4 | sibolga
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | mugur-aksy
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 4 | oriximina
# Processing Record 9 of Set 4 | burica
# City not found. Skipping...
# Processing Record 10 of Set 4 | mahibadhoo
# Processing Record 11 of Set 4 | drobak
# Processing Record 12 of Set 4 | lagos
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | walvis bay
# Processing Record 15 of Set 4 | port macquarie
# Processing Record 16 of Set 4 | hervey bay
# Processing Record 17 of Set 4 | iracoubo
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | warrnambool
# Processing Record 22 of Set 4 | kosonsoy
# Processing Record 23 of Set 4 | kholtoson
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | linares
# Processing Record 27 of Set 4 | rovaniemi
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | male
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | tasiilaq
# Processing Record 32 of Set 4 | asfi
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | del rio
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | jacqueville
# Processing Record 37 of Set 4 | xining
# Processing Record 38 of Set 4 | carroll
# Processing Record 39 of Set 4 | road town
# Processing Record 40 of Set 4 | bacolod
# Processing Record 41 of Set 4 | ayna
# Processing Record 42 of Set 4 | shorewood
# Processing Record 43 of Set 4 | kawalu
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | umm lajj
# Processing Record 46 of Set 4 | kodinsk
# Processing Record 47 of Set 4 | farkhor
# Processing Record 48 of Set 4 | carballo
# Processing Record 49 of Set 4 | omsukchan
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | conchas
# Processing Record 2 of Set 5 | camacha
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 5 | brigham city
# Processing Record 6 of Set 5 | roebourne
# Processing Record 7 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 5 | kota belud
# Processing Record 9 of Set 5 | yuncheng
# Processing Record 10 of Set 5 | moosomin
# Processing Record 11 of Set 5 | stonewall
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | burla
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | tiznit
# Processing Record 18 of Set 5 | tumaco
# Processing Record 19 of Set 5 | chambersburg
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | srednekolymsk
# Processing Record 22 of Set 5 | songjianghe
# Processing Record 23 of Set 5 | coahuayana
# Processing Record 24 of Set 5 | palmer
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | camabatela
# Processing Record 28 of Set 5 | las vegas
# Processing Record 29 of Set 5 | briancon
# Processing Record 30 of Set 5 | alekseyevsk
# Processing Record 31 of Set 5 | lasa
# Processing Record 32 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 5 | darhan
# Processing Record 34 of Set 5 | puerto quijarro
# Processing Record 35 of Set 5 | itarema
# Processing Record 36 of Set 5 | taiyuan
# Processing Record 37 of Set 5 | ewa beach
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | fairlie
# Processing Record 40 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 5 | nelson bay
# Processing Record 42 of Set 5 | okha
# Processing Record 43 of Set 5 | atar
# Processing Record 44 of Set 5 | west bay
# Processing Record 45 of Set 5 | kodiak
# Processing Record 46 of Set 5 | dalby
# Processing Record 47 of Set 5 | saint-philippe
# Processing Record 48 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 5 | williams lake
# Processing Record 50 of Set 5 | formosa
# Processing Record 1 of Set 6 | kindu
# Processing Record 2 of Set 6 | san isidro
# Processing Record 3 of Set 6 | magistralnyy
# Processing Record 4 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | greenville
# Processing Record 7 of Set 6 | lazo
# Processing Record 8 of Set 6 | leningradskiy
# Processing Record 9 of Set 6 | shatrovo
# Processing Record 10 of Set 6 | labrea
# Processing Record 11 of Set 6 | dakar
# Processing Record 12 of Set 6 | maldonado
# Processing Record 13 of Set 6 | lisakovsk
# Processing Record 14 of Set 6 | basoko
# Processing Record 15 of Set 6 | poum
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | vanimo
# Processing Record 19 of Set 6 | ivrea
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | muroto
# Processing Record 22 of Set 6 | ta khmau
# Processing Record 23 of Set 6 | yoichi
# Processing Record 24 of Set 6 | ishigaki
# Processing Record 25 of Set 6 | kayerkan
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 6 | richards bay
# Processing Record 29 of Set 6 | tecoanapa
# Processing Record 30 of Set 6 | port-cartier
# Processing Record 31 of Set 6 | havoysund
# Processing Record 32 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 33 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 6 | oktyabrskoye
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | warmbad
# Processing Record 37 of Set 6 | nalut
# Processing Record 38 of Set 6 | talagang
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | tahta
# Processing Record 41 of Set 6 | pavlivka
# Processing Record 42 of Set 6 | tabou
# Processing Record 43 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 6 | margate
# Processing Record 45 of Set 6 | alta floresta
# Processing Record 46 of Set 6 | khatanga
# Processing Record 47 of Set 6 | tombouctou
# Processing Record 48 of Set 6 | monte patria
# Processing Record 49 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | eravur
# Processing Record 2 of Set 7 | ilinskiy
# Processing Record 3 of Set 7 | qaqortoq
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | christchurch
# Processing Record 6 of Set 7 | chapais
# Processing Record 7 of Set 7 | muisne
# Processing Record 8 of Set 7 | beringovskiy
# Processing Record 9 of Set 7 | poopo
# Processing Record 10 of Set 7 | kuching
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | kazachinskoye
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | kloulklubed
# Processing Record 15 of Set 7 | bakchar
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | nikolskoye
# Processing Record 18 of Set 7 | winnemucca
# Processing Record 19 of Set 7 | kalianget
# Processing Record 20 of Set 7 | muros
# Processing Record 21 of Set 7 | hofn
# Processing Record 22 of Set 7 | upington
# Processing Record 23 of Set 7 | sangueya
# Processing Record 24 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 7 | korla
# Processing Record 26 of Set 7 | hammerfest
# Processing Record 27 of Set 7 | kizema
# Processing Record 28 of Set 7 | vinh
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | ferkessedougou
# Processing Record 31 of Set 7 | moose factory
# Processing Record 32 of Set 7 | severnoye
# Processing Record 33 of Set 7 | xacmaz
# Processing Record 34 of Set 7 | seymchan
# Processing Record 35 of Set 7 | haines junction
# Processing Record 36 of Set 7 | mari-turek
# Processing Record 37 of Set 7 | gamba
# Processing Record 38 of Set 7 | liyang
# Processing Record 39 of Set 7 | marawi
# Processing Record 40 of Set 7 | ketchikan
# Processing Record 41 of Set 7 | farafangana
# Processing Record 42 of Set 7 | augusto correa
# Processing Record 43 of Set 7 | phibun mangsahan
# Processing Record 44 of Set 7 | san rafael del sur
# Processing Record 45 of Set 7 | muzhi
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | olavarria
# Processing Record 48 of Set 7 | thinadhoo
# Processing Record 49 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 7 | fengzhen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27064\4082217692.py in <module>
#      17         set_count += 1
#      18         record_count = 1
# ---> 19         time.sleep(60)
#      20
#      21     # Create an endpoint URL for each city
#
# KeyboardInterrupt:

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_reorder = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_reorder]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
citi_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database.csv"

# Export the city_data DataFrame into a CSV file
city_datadf.to_csv(output_data_file, index_label="City_ID")
