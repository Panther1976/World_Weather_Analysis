# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao jose da coroa grande
# Processing Record 2 of Set 1 | tuymazy
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | komsomolskiy
# Processing Record 12 of Set 1 | solwezi
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | zhangye
# Processing Record 23 of Set 1 | lompoc
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | constitucion
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 1 | springbok
# Processing Record 30 of Set 1 | hofn
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | vorobyevka
# Processing Record 33 of Set 1 | sola
# Processing Record 34 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | tsuyama
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | ostrovnoy
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | carman
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | beloha
# Processing Record 1 of Set 2 | marsa matruh
# Processing Record 2 of Set 2 | worcester
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | baker city
# Processing Record 6 of Set 2 | penzance
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | dudinka
# Processing Record 10 of Set 2 | rawson
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | nha trang
# Processing Record 15 of Set 2 | piastow
# Processing Record 16 of Set 2 | narsaq
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | susurluk
# Processing Record 19 of Set 2 | conakry
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | cayenne
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | norden
# Processing Record 25 of Set 2 | tulagi
# Processing Record 26 of Set 2 | puerto escondido
# Processing Record 27 of Set 2 | conde
# Processing Record 28 of Set 2 | los reyes
# Processing Record 29 of Set 2 | bathsheba
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | paracelis
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | mayenne
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | aksu
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | ahipara
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | raudeberg
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | la plata
# Processing Record 49 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 3 | hambantota
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | znamenskoye
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | luderitz
# Processing Record 11 of Set 3 | saint george
# Processing Record 12 of Set 3 | korla
# Processing Record 13 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 3 | wamba
# Processing Record 15 of Set 3 | cockburn town
# Processing Record 16 of Set 3 | kaseda
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | wajima
# Processing Record 19 of Set 3 | kiama
# Processing Record 20 of Set 3 | mindyak
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | primorsko-akhtarsk
# Processing Record 25 of Set 3 | thinadhoo
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | sassandra
# Processing Record 29 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | leh
# Processing Record 32 of Set 3 | barahona
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | harlingen
# Processing Record 35 of Set 3 | grenaa
# Processing Record 36 of Set 3 | port augusta
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | belyy yar
# Processing Record 40 of Set 3 | te anau
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | fort nelson
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | nueva imperial
# Processing Record 49 of Set 3 | boueni
# Processing Record 50 of Set 3 | kasamwa
# Processing Record 1 of Set 4 | cap malheureux
# Processing Record 2 of Set 4 | coihaique
# Processing Record 3 of Set 4 | rio grande
# Processing Record 4 of Set 4 | kahului
# Processing Record 5 of Set 4 | borna
# Processing Record 6 of Set 4 | sirjan
# Processing Record 7 of Set 4 | salina
# Processing Record 8 of Set 4 | santa rosa
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | pitimbu
# Processing Record 12 of Set 4 | fare
# Processing Record 13 of Set 4 | dindori
# Processing Record 14 of Set 4 | sioux lookout
# Processing Record 15 of Set 4 | frederikshavn
# Processing Record 16 of Set 4 | ondjiva
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | toktogul
# Processing Record 19 of Set 4 | cherskiy
# Processing Record 20 of Set 4 | mocuba
# Processing Record 21 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | dahra
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | miri
# Processing Record 26 of Set 4 | barra do bugres
# Processing Record 27 of Set 4 | kibre mengist
# Processing Record 28 of Set 4 | taltal
# Processing Record 29 of Set 4 | walvis bay
# Processing Record 30 of Set 4 | methoni
# Processing Record 31 of Set 4 | yarada
# Processing Record 32 of Set 4 | camabatela
# Processing Record 33 of Set 4 | canon city
# Processing Record 34 of Set 4 | kizukuri
# Processing Record 35 of Set 4 | russell
# Processing Record 36 of Set 4 | aklavik
# Processing Record 37 of Set 4 | manta
# Processing Record 38 of Set 4 | lufilufi
# Processing Record 39 of Set 4 | wattegama
# Processing Record 40 of Set 4 | isla vista
# Processing Record 41 of Set 4 | cervo
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | port-gentil
# Processing Record 47 of Set 4 | saint anthony
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | sao pedro do piaui
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | eyl
# Processing Record 2 of Set 5 | port-cartier
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | villarrica
# Processing Record 5 of Set 5 | dwarka
# Processing Record 6 of Set 5 | paamiut
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | nizhnevartovsk
# Processing Record 10 of Set 5 | golden gate
# Processing Record 11 of Set 5 | kidal
# Processing Record 12 of Set 5 | baykit
# Processing Record 13 of Set 5 | papara
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | ondangwa
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | egvekinot
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | manoel urbano
# Processing Record 21 of Set 5 | yokadouma
# Processing Record 22 of Set 5 | vardo
# Processing Record 23 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 5 | charlton
# Processing Record 25 of Set 5 | oneida
# Processing Record 26 of Set 5 | la rioja
# Processing Record 27 of Set 5 | fredericton
# Processing Record 28 of Set 5 | venice
# Processing Record 29 of Set 5 | dalbeattie
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | lincoln
# Processing Record 32 of Set 5 | port blair
# Processing Record 33 of Set 5 | guerrero negro
# Processing Record 34 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 5 | cozumel
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | tandil
# Processing Record 38 of Set 5 | severobaykalsk
# Processing Record 39 of Set 5 | mahon
# Processing Record 40 of Set 5 | awbari
# Processing Record 41 of Set 5 | dunmore town
# Processing Record 42 of Set 5 | pontes e lacerda
# Processing Record 43 of Set 5 | sawakin
# Processing Record 44 of Set 5 | beberibe
# Processing Record 45 of Set 5 | manaure
# Processing Record 46 of Set 5 | talara
# Processing Record 47 of Set 5 | udachnyy
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | hovd
# Processing Record 50 of Set 5 | panalingaan
# Processing Record 1 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 6 | moranbah
# Processing Record 3 of Set 6 | waingapu
# Processing Record 4 of Set 6 | minsk
# Processing Record 5 of Set 6 | poum
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | karatau
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | galle
# Processing Record 10 of Set 6 | kilindoni
# Processing Record 11 of Set 6 | ormara
# Processing Record 12 of Set 6 | aykhal
# Processing Record 13 of Set 6 | taksimo
# Processing Record 14 of Set 6 | clyde river
# Processing Record 15 of Set 6 | mogadishu
# Processing Record 16 of Set 6 | halifax
# Processing Record 17 of Set 6 | huambo
# Processing Record 18 of Set 6 | khatanga
# Processing Record 19 of Set 6 | mercedes
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | henderson
# Processing Record 22 of Set 6 | boyle
# Processing Record 23 of Set 6 | barra patuca
# Processing Record 24 of Set 6 | nemuro
# Processing Record 25 of Set 6 | ust-nera
# Processing Record 26 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 6 | banff
# Processing Record 28 of Set 6 | innisfail
# Processing Record 29 of Set 6 | trelew
# Processing Record 30 of Set 6 | lamont
# Processing Record 31 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 6 | fuzhou
# Processing Record 33 of Set 6 | nong bua
# Processing Record 34 of Set 6 | pacifica
# Processing Record 35 of Set 6 | pochutla
# Processing Record 36 of Set 6 | road town
# Processing Record 37 of Set 6 | aktash
# Processing Record 38 of Set 6 | seoul
# Processing Record 39 of Set 6 | grants
# Processing Record 40 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | maloy
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | minab
# Processing Record 45 of Set 6 | tena
# Processing Record 46 of Set 6 | mayo
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | srednekolymsk
# Processing Record 49 of Set 6 | whitehorse
# Processing Record 50 of Set 6 | buala
# Processing Record 1 of Set 7 | barras
# Processing Record 2 of Set 7 | bonthe
# Processing Record 3 of Set 7 | melfi
# Processing Record 4 of Set 7 | balakovo
# Processing Record 5 of Set 7 | pleshanovo
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | tabou
# Processing Record 8 of Set 7 | west helena
# Processing Record 9 of Set 7 | aloleng
# Processing Record 10 of Set 7 | bardiyah
# Processing Record 11 of Set 7 | saskylakh
# Processing Record 12 of Set 7 | tautira
# Processing Record 13 of Set 7 | kapoeta
# Processing Record 14 of Set 7 | maceio
# Processing Record 15 of Set 7 | tura
# Processing Record 16 of Set 7 | yerbogachen
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | roswell
# Processing Record 19 of Set 7 | berekum
# Processing Record 20 of Set 7 | khaniotis
# Processing Record 21 of Set 7 | san fernando
# Processing Record 22 of Set 7 | bathurst
# Processing Record 23 of Set 7 | cacequi
# Processing Record 24 of Set 7 | nikolskoye
# Processing Record 25 of Set 7 | ayia anna
# Processing Record 26 of Set 7 | luganville
# Processing Record 27 of Set 7 | nome
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | roebourne
# Processing Record 30 of Set 7 | margate
# Processing Record 31 of Set 7 | barcelos
# Processing Record 32 of Set 7 | havre-saint-pierre
# Processing Record 33 of Set 7 | nampula
# Processing Record 34 of Set 7 | pinawa
# Processing Record 35 of Set 7 | broome
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | saint-louis
# Processing Record 40 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | bharatpur
# Processing Record 42 of Set 7 | gbadolite
# Processing Record 43 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 44 of Set 7 | lagoa
# Processing Record 45 of Set 7 | agadir
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | phan thiet
# Processing Record 48 of Set 7 | campos belos
# Processing Record 49 of Set 7 | perbaungan
# Processing Record 50 of Set 7 | portel
# Processing Record 1 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 2 of Set 8 | oktyabrskoye
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | tuy hoa
# Processing Record 5 of Set 8 | tres arroyos
# Processing Record 6 of Set 8 | suhbaatar
# Processing Record 7 of Set 8 | sur
# Processing Record 8 of Set 8 | bafoulabe
# Processing Record 9 of Set 8 | zabol
# Processing Record 10 of Set 8 | aksarka
# Processing Record 11 of Set 8 | dongning
# Processing Record 12 of Set 8 | tasiilaq
# Processing Record 13 of Set 8 | kapit
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | chuy
# Processing Record 16 of Set 8 | moron
# Processing Record 17 of Set 8 | medina
# Processing Record 18 of Set 8 | batagay-alyta
# Processing Record 19 of Set 8 | umm lajj
# Processing Record 20 of Set 8 | ende
# Processing Record 21 of Set 8 | svetlogorsk
# Processing Record 22 of Set 8 | chicama
# Processing Record 23 of Set 8 | mao
# Processing Record 24 of Set 8 | kalmunai
# Processing Record 25 of Set 8 | velingara
# Processing Record 26 of Set 8 | padang
# Processing Record 27 of Set 8 | pandan
# Processing Record 28 of Set 8 | uchiza
# Processing Record 29 of Set 8 | nago
# Processing Record 30 of Set 8 | nishihara
# Processing Record 31 of Set 8 | nexo
# Processing Record 32 of Set 8 | puerto madero
# Processing Record 33 of Set 8 | coruripe
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | yatou
# Processing Record 36 of Set 8 | madera
# Processing Record 37 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | macherla
# Processing Record 40 of Set 8 | midleton
# Processing Record 41 of Set 8 | san policarpo
# Processing Record 42 of Set 8 | talnakh
# Processing Record 43 of Set 8 | crotone
# Processing Record 44 of Set 8 | kavaratti
# Processing Record 45 of Set 8 | ruteng
# Processing Record 46 of Set 8 | gat
# Processing Record 47 of Set 8 | derzhavinsk
# Processing Record 48 of Set 8 | portland
# Processing Record 49 of Set 8 | bubaque
# Processing Record 50 of Set 8 | huarmey
# Processing Record 1 of Set 9 | lerwick
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | ngora
# Processing Record 4 of Set 9 | tosno
# Processing Record 5 of Set 9 | filadelfia
# Processing Record 6 of Set 9 | futtsu
# Processing Record 7 of Set 9 | asadabad
# Processing Record 8 of Set 9 | saint-georges
# Processing Record 9 of Set 9 | baghdad
# Processing Record 10 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 9 | jumla
# Processing Record 12 of Set 9 | nantucket
# Processing Record 13 of Set 9 | leningradskiy
# Processing Record 14 of Set 9 | tual
# Processing Record 15 of Set 9 | siderno
# Processing Record 16 of Set 9 | najran
# Processing Record 17 of Set 9 | balakhta
# Processing Record 18 of Set 9 | troitsko-pechorsk
# Processing Record 19 of Set 9 | muncar
# Processing Record 20 of Set 9 | matagami
# Processing Record 21 of Set 9 | sapa
# Processing Record 22 of Set 9 | la crosse
# Processing Record 23 of Set 9 | qaqortoq
# Processing Record 24 of Set 9 | izumo
# Processing Record 25 of Set 9 | birjand
# Processing Record 26 of Set 9 | sturgeon bay
# Processing Record 27 of Set 9 | nobres
# Processing Record 28 of Set 9 | aguimes
# Processing Record 29 of Set 9 | is
# City not found. Skipping...
# Processing Record 30 of Set 9 | esperance
# Processing Record 31 of Set 9 | bekovo
# Processing Record 32 of Set 9 | yanai
# Processing Record 33 of Set 9 | tromso
# Processing Record 34 of Set 9 | sosnovo-ozerskoye
# Processing Record 35 of Set 9 | chhatapur
# Processing Record 36 of Set 9 | dahod
# Processing Record 37 of Set 9 | kyra
# Processing Record 38 of Set 9 | banepa
# Processing Record 39 of Set 9 | koslan
# Processing Record 40 of Set 9 | zholymbet
# Processing Record 41 of Set 9 | dunkirk
# Processing Record 42 of Set 9 | hushitai
# Processing Record 43 of Set 9 | sept-iles
# Processing Record 44 of Set 9 | kribi
# Processing Record 45 of Set 9 | liminangcong
# City not found. Skipping...
# Processing Record 46 of Set 9 | port lincoln
# Processing Record 47 of Set 9 | baykalovo
# Processing Record 48 of Set 9 | mumford
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | great yarmouth
# Processing Record 1 of Set 10 | jiujiang
# Processing Record 2 of Set 10 | roma
# Processing Record 3 of Set 10 | kedrovyy
# Processing Record 4 of Set 10 | hualmay
# Processing Record 5 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 10 | abilene
# Processing Record 7 of Set 10 | henties bay
# Processing Record 8 of Set 10 | salalah
# Processing Record 9 of Set 10 | henin-beaumont
# Processing Record 10 of Set 10 | haflong
# Processing Record 11 of Set 10 | ust-tsilma
# Processing Record 12 of Set 10 | kabanjahe
# Processing Record 13 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 10 | vila velha
# Processing Record 15 of Set 10 | montevideo
# Processing Record 16 of Set 10 | samarai
# Processing Record 17 of Set 10 | bocas del toro
# Processing Record 18 of Set 10 | bintulu
# Processing Record 19 of Set 10 | assiniboia
# Processing Record 20 of Set 10 | livingston
# Processing Record 21 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 10 | kangaatsiaq
# Processing Record 23 of Set 10 | mareeba
# Processing Record 24 of Set 10 | cabedelo
# Processing Record 25 of Set 10 | orlovka
# Processing Record 26 of Set 10 | marzuq
# Processing Record 27 of Set 10 | puerto penasco
# Processing Record 28 of Set 10 | palauig
# Processing Record 29 of Set 10 | honiara
# Processing Record 30 of Set 10 | jalu
# Processing Record 31 of Set 10 | tocache
# Processing Record 32 of Set 10 | catamarca
# Processing Record 33 of Set 10 | pisco
# Processing Record 34 of Set 10 | eureka
# Processing Record 35 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 10 | iralaya
# Processing Record 37 of Set 10 | changping
# Processing Record 38 of Set 10 | wanning
# Processing Record 39 of Set 10 | lavrentiya
# Processing Record 40 of Set 10 | pierre
# Processing Record 41 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 10 | blairmore
# Processing Record 43 of Set 10 | santiago del estero
# Processing Record 44 of Set 10 | lata
# Processing Record 45 of Set 10 | agua verde
# Processing Record 46 of Set 10 | moose factory
# Processing Record 47 of Set 10 | hazorasp
# Processing Record 48 of Set 10 | kerema
# Processing Record 49 of Set 10 | sai buri
# Processing Record 50 of Set 10 | naze
# Processing Record 1 of Set 11 | pringsewu
# Processing Record 2 of Set 11 | larap
# Processing Record 3 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 11 | blythe
# Processing Record 5 of Set 11 | presidente epitacio
# Processing Record 6 of Set 11 | pyapon
# Processing Record 7 of Set 11 | flinders
# Processing Record 8 of Set 11 | saurimo
# Processing Record 9 of Set 11 | maniitsoq
# Processing Record 10 of Set 11 | atar
# Processing Record 11 of Set 11 | chimoio
# Processing Record 12 of Set 11 | barra do garcas
# Processing Record 13 of Set 11 | teya
# Processing Record 14 of Set 11 | hobyo
# Processing Record 15 of Set 11 | mangile
# City not found. Skipping...
# Processing Record 16 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 11 | banikoara
# Processing Record 19 of Set 11 | gambela
# Processing Record 20 of Set 11 | verkh-suetka
# Processing Record 21 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 22 of Set 11 | tuatapere
# Processing Record 23 of Set 11 | mazagao
# Processing Record 24 of Set 11 | safaga
# Processing Record 25 of Set 11 | huoqiu
# Processing Record 26 of Set 11 | garden city
# Processing Record 27 of Set 11 | nikolayevsk-na-amure
# Processing Record 28 of Set 11 | oromocto
# Processing Record 29 of Set 11 | vuktyl
# Processing Record 30 of Set 11 | chiang khong
# Processing Record 31 of Set 11 | ranong
# Processing Record 32 of Set 11 | qinggang
# Processing Record 33 of Set 11 | progress
# Processing Record 34 of Set 11 | sistranda
# Processing Record 35 of Set 11 | qobustan
# Processing Record 36 of Set 11 | bitlis
# Processing Record 37 of Set 11 | katobu
# Processing Record 38 of Set 11 | civitavecchia
# Processing Record 39 of Set 11 | bilibino
# Processing Record 40 of Set 11 | vredendal
# Processing Record 41 of Set 11 | jagatsinghapur
# Processing Record 42 of Set 11 | worland
# Processing Record 43 of Set 11 | dingle
# Processing Record 44 of Set 11 | pangody
# Processing Record 45 of Set 11 | lapua
# Processing Record 46 of Set 11 | tonstad
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 11 | wahiawa
# Processing Record 50 of Set 11 | sergeyevka
# Processing Record 1 of Set 12 | constantine
# Processing Record 2 of Set 12 | alyangula
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | kakonko
# Processing Record 5 of Set 12 | bozoum
# Processing Record 6 of Set 12 | mantua
# Processing Record 7 of Set 12 | champerico
# Processing Record 8 of Set 12 | mackay
# Processing Record 9 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 12 | san ignacio
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | ferrol
# Processing Record 13 of Set 12 | azul
# Processing Record 14 of Set 12 | salinas
# Processing Record 15 of Set 12 | magdagachi
# Processing Record 16 of Set 12 | turka
# Processing Record 17 of Set 12 | sinnamary
# Processing Record 18 of Set 12 | launceston
# Processing Record 19 of Set 12 | belogorsk
# Processing Record 20 of Set 12 | wad madani
# Processing Record 21 of Set 12 | elizabeth city
# Processing Record 22 of Set 12 | emba
# Processing Record 23 of Set 12 | buchanan
# Processing Record 24 of Set 12 | dole
# Processing Record 25 of Set 12 | moengo
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | berlevag
# Processing Record 28 of Set 12 | odweyne
# Processing Record 29 of Set 12 | ust-maya
# Processing Record 30 of Set 12 | zainsk
# Processing Record 31 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 12 | olafsvik
# Processing Record 33 of Set 12 | flic en flac
# Processing Record 34 of Set 12 | nenjiang
# Processing Record 35 of Set 12 | honningsvag
# Processing Record 36 of Set 12 | tevriz
# Processing Record 37 of Set 12 | naryan-mar
# Processing Record 38 of Set 12 | tocopilla
# Processing Record 39 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | digha
# Processing Record 42 of Set 12 | betare oya
# Processing Record 43 of Set 12 | onega
# Processing Record 44 of Set 12 | kotovo
# Processing Record 45 of Set 12 | iracoubo
# Processing Record 46 of Set 12 | port hardy
# Processing Record 47 of Set 12 | opuwo
# Processing Record 48 of Set 12 | navolato
# Processing Record 49 of Set 12 | pag
# Processing Record 50 of Set 12 | fontenay-le-comte
# Processing Record 1 of Set 13 | novochernorechenskiy
# Processing Record 2 of Set 13 | bacolod
# Processing Record 3 of Set 13 | nelson bay
# Processing Record 4 of Set 13 | the pas
# Processing Record 5 of Set 13 | lakki marwat
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | galesong
# Processing Record 8 of Set 13 | atbasar
# Processing Record 9 of Set 13 | cacheu
# Processing Record 10 of Set 13 | bonavista
# Processing Record 11 of Set 13 | inhambane
# Processing Record 12 of Set 13 | panaba
# Processing Record 13 of Set 13 | gori
# Processing Record 14 of Set 13 | morondava
# Processing Record 15 of Set 13 | mayumba
# Processing Record 16 of Set 13 | camana
# Processing Record 17 of Set 13 | sterling
# Processing Record 18 of Set 13 | tarko-sale
# Processing Record 19 of Set 13 | wladyslawowo
# Processing Record 20 of Set 13 | kiunga
# Processing Record 21 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 13 | gaeta
# Processing Record 23 of Set 13 | erenhot
# Processing Record 24 of Set 13 | urumqi
# Processing Record 25 of Set 13 | namibe
# Processing Record 26 of Set 13 | kayes
# Processing Record 27 of Set 13 | nueva esperanza
# Processing Record 28 of Set 13 | camopi
# Processing Record 29 of Set 13 | athabasca
# Processing Record 30 of Set 13 | sakaiminato
# Processing Record 31 of Set 13 | san cristobal
# Processing Record 32 of Set 13 | jacqueville
# Processing Record 33 of Set 13 | piracuruca
# Processing Record 34 of Set 13 | isiro
# Processing Record 35 of Set 13 | iquique
# Processing Record 36 of Set 13 | katherine
# Processing Record 37 of Set 13 | puerto quijarro
# Processing Record 38 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 13 | viransehir
# Processing Record 40 of Set 13 | nisia floresta
# Processing Record 41 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 13 | berezovyy
# Processing Record 43 of Set 13 | traralgon
# Processing Record 44 of Set 13 | inta
# Processing Record 45 of Set 13 | ilhabela
# Processing Record 46 of Set 13 | podyuga
# Processing Record 47 of Set 13 | kysyl-syr
# Processing Record 48 of Set 13 | skibbereen
# Processing Record 49 of Set 13 | xam nua
# Processing Record 50 of Set 13 | ganzhou
# Processing Record 1 of Set 14 | nanortalik
# Processing Record 2 of Set 14 | raga
# Processing Record 3 of Set 14 | dezful
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | gumla
# Processing Record 6 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 7 of Set 14 | evinayong
# Processing Record 8 of Set 14 | sawtell
# Processing Record 9 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 10 of Set 14 | kouango
# Processing Record 11 of Set 14 | kurilsk
# Processing Record 12 of Set 14 | asfi
# Processing Record 13 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 14 | sulangan
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | majdanpek
# Processing Record 17 of Set 14 | abashiri
# Processing Record 18 of Set 14 | puerres
# Processing Record 19 of Set 14 | ixtapa
# Processing Record 20 of Set 14 | santa teresa
# Processing Record 21 of Set 14 | northam
# Processing Record 22 of Set 14 | ak-dovurak
# Processing Record 23 of Set 14 | bontang
# Processing Record 24 of Set 14 | lucea
# Processing Record 25 of Set 14 | batabano
# Processing Record 26 of Set 14 | north platte
# Processing Record 27 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 14 | karratha
# Processing Record 29 of Set 14 | mbandaka
# Processing Record 30 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 14 | krasnoselkup
# Processing Record 32 of Set 14 | sabang
# Processing Record 33 of Set 14 | isangel
# Processing Record 34 of Set 14 | porto santo
# Processing Record 35 of Set 14 | vila
# Processing Record 36 of Set 14 | powell river
# Processing Record 37 of Set 14 | laguna
# Processing Record 38 of Set 14 | babynino
# Processing Record 39 of Set 14 | chirongui
# Processing Record 40 of Set 14 | bourail
# Processing Record 41 of Set 14 | paoua
# Processing Record 42 of Set 14 | luba
# Processing Record 43 of Set 14 | minuri
# Processing Record 44 of Set 14 | serov
# Processing Record 45 of Set 14 | knysna
# Processing Record 46 of Set 14 | flin flon
# Processing Record 47 of Set 14 | nyrob
# Processing Record 48 of Set 14 | kloulklubed
# Processing Record 49 of Set 14 | pakokku
# Processing Record 50 of Set 14 | vestmannaeyjar
# Processing Record 1 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 15 | yeppoon
# Processing Record 3 of Set 15 | nizhniy tsasuchey
# Processing Record 4 of Set 15 | bukit bakri
# City not found. Skipping...
# Processing Record 5 of Set 15 | adre
# Processing Record 6 of Set 15 | westport
# Processing Record 7 of Set 15 | kirakira
# Processing Record 8 of Set 15 | sibu
# Processing Record 9 of Set 15 | sao joao da barra
# Processing Record 10 of Set 15 | deming
# Processing Record 11 of Set 15 | japura
# Processing Record 12 of Set 15 | tilichiki
# Processing Record 13 of Set 15 | alexandria
# Processing Record 14 of Set 15 | vostok
# Processing Record 15 of Set 15 | viedma
# Processing Record 16 of Set 15 | bitung
# Processing Record 17 of Set 15 | liepaja
# Processing Record 18 of Set 15 | tonantins
# Processing Record 19 of Set 15 | fostoria
# Processing Record 20 of Set 15 | goure
# Processing Record 21 of Set 15 | oyama
# Processing Record 22 of Set 15 | grand gaube
# Processing Record 23 of Set 15 | goderich
# Processing Record 24 of Set 15 | mahanoro
# Processing Record 25 of Set 15 | aleksandrov gay
# Processing Record 26 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 15 | kismayo
# Processing Record 28 of Set 15 | arrifes
# Processing Record 29 of Set 15 | rocha
# Processing Record 30 of Set 15 | yenotayevka
# Processing Record 31 of Set 15 | sao paulo de olivenca
# Processing Record 32 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 15 | evensk
# Processing Record 34 of Set 15 | damghan
# Processing Record 35 of Set 15 | qianan
# Processing Record 36 of Set 15 | carutapera
# Processing Record 37 of Set 15 | yenagoa
# Processing Record 38 of Set 15 | los cedrales
# Processing Record 39 of Set 15 | dedza
# Processing Record 40 of Set 15 | vilhena
# Processing Record 41 of Set 15 | sechura
# Processing Record 42 of Set 15 | kieta
# Processing Record 43 of Set 15 | terney
# Processing Record 44 of Set 15 | jinchang
# Processing Record 45 of Set 15 | saint-michel-des-saints
# Processing Record 46 of Set 15 | tiznit
# Processing Record 47 of Set 15 | dalvik
# Processing Record 48 of Set 15 | dubbo
# Processing Record 49 of Set 15 | bayir
# Processing Record 50 of Set 15 | majene
# Processing Record 1 of Set 16 | macau
# Processing Record 2 of Set 16 | guilin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_reorder = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_reorder]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
citi_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database.csv"

# Export the city_data DataFrame into a CSV file
city_datadf.to_csv(output_data_file, index_label="City_ID")
